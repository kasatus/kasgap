# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_table('../data/sampleData.tsv', sep='\t')
colArray = dataset.columns

# %%
# cleaning up training data:
# 1. Removing IDs
list = []
for col in colArray:
    list.append(col.replace("ibsa_main_sample_set.", ""))

for s in list:
    print(s)
# Out:
# innovation_challenge_key
# renewed_yorn
# instance_id
# contract_line_id
# minor_line_yorn
# major_line_instance_id
# installation_date
# product_sales_order_type
# product_purchase_order_type
# instance_status
# product_transaction_type
# installed_product_type
# installed_product_component_yorn
# component_type
# scdc_product_yorn
# service_classification
# service_contract_last_renewal_date
# service_contract_classification
# service_contract_process_type
# contract_line_multi_year_discount_yorn
# contract_line_route_to_market_code
# contract_line_duration_in_days
# contract_line_start_date
# contract_line_end_date
# contract_line_create_date
# contract_line_sales_motion_code
# marketing_program_name
# default_multi_year_discount_yorn
# service_contract_discount_percentage
# low_dollar_contract_yorn
# warranty_type
# warranty_contract_line_start_date
# warranty_contract_line_end_date
# contract_line_source_business_process_name
# contract_line_repair_service_order_level
# ...
